# %% [markdown]
# # 🐙 Tutoriel pour l'utilisation de **Kami** (Kraken Model Inspector)
# <br>
#
# Ce tutoriel a été élaboré par **Lucas Terriel** (Inria - ALMAnaCH) et **Alix Chagué** (Inria - ALMAnaCH) et publié sur le dépôt du projet [Kami](https://gitlab.inria.fr/dh-projects/kami/kami-lib)  ([pour citer le projet](https://gitlab.inria.fr/dh-projects/kami/kami-lib/-/blob/master/CITATION.CFF)).
#
# Nous en avons simplifié l'écriture pour une utilisation exclusivement locale (le [tutoriel original](https://cutt.ly/WT3Ahx1) est publié sur Google Collab).
#
# Date de la version utilisée : 24/08/2021.
#
#
# ## Introduction
#
# Ce notebook vise à présenter l'utilisation du *package* Python **Kami** à travers l'exemple d'une chaîne de traitement complète : import des données => résultats du modèle HTR/OCR => export des résultats en CSV

# %% [markdown]
# ## Étape préliminaire : Installation du *package* Python Kami
# 🚀 Lancer la cellule et attendre la fin de l'exécution. (Cela peut prendre un certain temps)
#
# ⚠️ **N.B.** : *Ignorer les erreurs relatives à l'installation des packages scikit-learn, torch et torchtext, à la fin de l'éxecution de la cellule. (erreurs inhérentes à google colab, relancer la cellule les erreurs disparaissent)*

# %%
# vérification de la version Python utilisé 
# !python --version
# installation des packages nécéssaires
# !pip install kamilib
#!pip install -i https://test.pypi.org/simple/ kamilib
# lister vos dépendances en dé-commentant la ligne qui suit
# !pip freeze
# Out:
# Python 3.8.10
# Requirement already satisfied: kamilib in /home/sbiay/dhi/venv/lib/python3.8/site-packages (0.1.2)
# Requirement already satisfied: cython in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kamilib) (0.29.28)
# Requirement already satisfied: torch==1.9.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kamilib) (1.9.0)
# Requirement already satisfied: python-Levenshtein==0.12.2 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kamilib) (0.12.2)
# Requirement already satisfied: kraken==3.0.6 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kamilib) (3.0.6)
# Requirement already satisfied: torchvision==0.10.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kamilib) (0.10.0)
# Requirement already satisfied: termcolor==1.1.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kamilib) (1.1.0)
# Requirement already satisfied: Unidecode in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kamilib) (1.3.4)
# Requirement already satisfied: jinja2 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (3.1.1)
# Requirement already satisfied: coremltools>=3.3 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (5.2.0)
# Requirement already satisfied: scipy in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (1.8.0)
# Requirement already satisfied: click>=7.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (8.1.2)
# Requirement already satisfied: numpy in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (1.22.3)
# Requirement already satisfied: scikit-image>=0.17.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (0.19.2)
# Requirement already satisfied: Pillow>=6.2.2 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (9.1.0)
# Requirement already satisfied: jsonschema in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (4.4.0)
# Requirement already satisfied: protobuf>=3.0.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (3.20.1)
# Requirement already satisfied: python-bidi in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (0.4.2)
# Requirement already satisfied: shapely in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (1.8.1.post1)
# Requirement already satisfied: lxml in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (4.6.4)
# Requirement already satisfied: requests in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (2.27.1)
# Requirement already satisfied: regex in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from kraken==3.0.6->kamilib) (2022.4.24)
# Requirement already satisfied: setuptools in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from python-Levenshtein==0.12.2->kamilib) (60.2.0)
# Requirement already satisfied: typing-extensions in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from torch==1.9.0->kamilib) (4.2.0)
# Requirement already satisfied: tqdm in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from coremltools>=3.3->kraken==3.0.6->kamilib) (4.64.0)
# Requirement already satisfied: packaging in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from coremltools>=3.3->kraken==3.0.6->kamilib) (21.3)
# Requirement already satisfied: sympy in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from coremltools>=3.3->kraken==3.0.6->kamilib) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from scikit-image>=0.17.0->kraken==3.0.6->kamilib) (2.8)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from scikit-image>=0.17.0->kraken==3.0.6->kamilib) (2022.4.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from scikit-image>=0.17.0->kraken==3.0.6->kamilib) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from scikit-image>=0.17.0->kraken==3.0.6->kamilib) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from jinja2->kraken==3.0.6->kamilib) (2.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from jsonschema->kraken==3.0.6->kamilib) (5.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from jsonschema->kraken==3.0.6->kamilib) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from jsonschema->kraken==3.0.6->kamilib) (0.18.1)
# Requirement already satisfied: six in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from python-bidi->kraken==3.0.6->kamilib) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from requests->kraken==3.0.6->kamilib) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from requests->kraken==3.0.6->kamilib) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from requests->kraken==3.0.6->kamilib) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from requests->kraken==3.0.6->kamilib) (2.0.12)
# Requirement already satisfied: zipp>=3.1.0 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema->kraken==3.0.6->kamilib) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from packaging->coremltools>=3.3->kraken==3.0.6->kamilib) (3.0.8)
# Requirement already satisfied: mpmath>=0.19 in /home/sbiay/dhi/venv/lib/python3.8/site-packages (from sympy->coremltools>=3.3->kraken==3.0.6->kamilib) (1.2.1)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/sbiay/dhi/venv/bin/python -m pip install --upgrade pip' command.
# absl-py==1.0.0
# aiohttp==3.8.1
# aiosignal==1.2.0
# albumentations==1.1.0
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.0.5
# async-timeout==4.0.2
# attrs==21.4.0
# backcall==0.2.0
# beautifulsoup4==4.11.1
# bleach==5.0.0
# blis==0.7.7
# bs4==0.0.1
# cachetools==5.0.0
# catalogue==2.0.7
# certifi==2021.10.8
# cffi==1.15.0
# charset-normalizer==2.0.12
# click==8.1.2
# commonmark==0.9.1
# coremltools==5.2.0
# cymem==2.0.6
# Cython==0.29.28
# debugpy==1.6.0
# decorator==5.1.1
# defusedxml==0.7.1
# entrypoints==0.4
# executing==0.8.3
# fastjsonschema==2.15.3
# fr-core-news-sm @ https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.2.0/fr_core_news_sm-3.2.0-py3-none-any.whl
# frozenlist==1.3.0
# fsspec==2022.3.0
# google-auth==2.6.6
# google-auth-oauthlib==0.4.6
# grpcio==1.44.0
# htrvx==0.0.9
# idna==3.3
# imageio==2.18.0
# importlib-metadata==4.11.3
# importlib-resources==5.7.1
# inexactsearch==1.0.2
# ipykernel==6.13.0
# ipython==8.2.0
# ipython-genutils==0.2.0
# ipywidgets==7.7.0
# jedi==0.18.1
# Jinja2==3.1.1
# joblib==1.1.0
# jsonschema==4.4.0
# jupyter==1.0.0
# jupyter-client==7.2.2
# jupyter-console==6.4.3
# jupyter-core==4.10.0
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==1.1.0
# kamilib==0.1.2
# kraken==3.0.6
# langcodes==3.3.0
# lxml==4.6.4
# Markdown==3.3.6
# MarkupSafe==2.1.1
# matplotlib-inline==0.1.3
# mistune==0.8.4
# mpmath==1.2.1
# multidict==6.0.2
# murmurhash==1.0.6
# nbclient==0.6.0
# nbconvert==6.5.0
# nbformat==5.3.0
# nest-asyncio==1.5.5
# networkx==2.8
# notebook==6.4.11
# numpy==1.22.3
# oauthlib==3.2.0
# opencv-python-headless==4.5.5.64
# packaging==21.3
# pandas==1.4.2
# pandocfilters==1.5.0
# parso==0.8.3
# pathy==0.6.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==9.1.0
# preshed==3.0.6
# prometheus-client==0.14.1
# prompt-toolkit==3.0.29
# protobuf==3.20.1
# psutil==5.9.0
# ptyprocess==0.7.0
# pure-eval==0.2.2
# pyarrow==7.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycparser==2.21
# pydantic==1.8.2
# pyDeprecate==0.3.2
# Pygments==2.12.0
# pyparsing==3.0.8
# pyrsistent==0.18.1
# pyspellchecker==0.5.6
# python-bidi==0.4.2
# python-dateutil==2.8.2
# python-Levenshtein==0.12.2
# pytorch-lightning==1.6.1
# pytz==2022.1
# PyWavelets==1.3.0
# PyYAML==6.0
# pyzmq==22.3.0
# qtconsole==5.3.0
# QtPy==2.0.1
# qudida==0.0.4
# regex==2022.4.24
# requests==2.27.1
# requests-oauthlib==1.3.1
# rich==12.3.0
# rsa==4.8
# scikit-image==0.19.2
# scikit-learn==1.0.2
# scipy==1.8.0
# Send2Trash==1.8.0
# Shapely==1.8.1.post1
# silpa-common==0.3
# six==1.16.0
# smart-open==5.2.1
# soundex==1.1.3
# soupsieve==2.3.2.post1
# spacy==3.2.4
# spacy-legacy==3.0.9
# spacy-loggers==1.0.2
# spellchecker==0.4
# srsly==2.4.3
# stack-data==0.2.0
# sympy==1.10.1
# tensorboard==2.8.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# termcolor==1.1.0
# terminado==0.13.3
# thinc==8.0.15
# threadpoolctl==3.1.0
# tifffile==2022.4.26
# tinycss2==1.1.1
# torch==1.9.0
# torchmetrics==0.8.1
# torchvision==0.10.0
# tornado==6.1
# tqdm==4.64.0
# traitlets==5.1.1
# typer==0.4.1
# typing_extensions==4.2.0
# Unidecode==1.3.4
# urllib3==1.26.9
# wasabi==0.9.1
# wcwidth==0.2.5
# webencodings==0.5.1
# Werkzeug==2.1.1
# widgetsnbextension==3.6.0
# yarl==1.7.2
# zipp==3.8.0

# %% [markdown]
# ## Étape 1 : Importer les *packages* Python pour la chaîne de traitement
#
# 🚀 Lancer la cellule.
#
# ⚠️ **N.B** : *Ignorer les warnings de dépréciations ... (relancer la cellule pour les faire disparaître)*

# %%
import csv
from datetime import datetime
import io
import pprint

import pandas as pd

from kami.Kami import Kami
# Out:
# WARNING:root:scikit-learn version 1.0.2 is not supported. Minimum required version: 0.17. Maximum required version: 0.19.2. Disabling scikit-learn conversion API.

# %% [markdown]
# ## Étape 2 : Tester le *package* Kami
#
# 🚀 Lancer la cellule.
#
# ✔️ **N.B** : *Si le code s'exécute avec succès, vous pouvez passer à la suite du notebook.*

# %%
# deux phrases d'exemples
ground_truth = "1: J'aime Python comme langage de programmation !!"
hypothesis = "2: J'adore python comme langage de développement web ?"

# Appel de la classe
k = Kami([ground_truth, hypothesis], verbosity=False, truncate=True, percent=True, round_digits='0.01')

# Affichage des phrases d'exemples
reference = k.reference
prediction = k.prediction


print("--------------------")
print(reference)
print("--------------------")
print(prediction)
print("--------------------")

pprint.pprint(k.scores.board)
# Out:
# --------------------
# 1: J'aime Python comme langage de programmation !!
# --------------------
# 2: J'adore python comme langage de développement web ?
# --------------------
# {'cer': 42.0,
#  'cil': 59.66,
#  'cip': 40.33,
#  'deletions': 0,
#  'hamming_distance': 'Ø',
#  'hits': 33,
#  'insertions': 4,
#  'levensthein_distance_char': 21,
#  'levensthein_distance_words': 6,
#  'mer': 38.88,
#  'substitutions': 17,
#  'wacc': 25.0,
#  'wer': 75.0,
#  'wer_hunt': 68.75}

# %% [markdown]
# ## Étape 3 : Importer les données (image, vérité terrain, et modèle HTR/OCR Kraken)
#
# ⚠️ Attention, si vous redémaré le noyau du notebook, vos données disparaissent, il est nécéssaire de les importer à nouveau.

# %% [markdown]
# On indiquer le chemin vers les données :

# %%
# ground_truth est un chemin vers un fichier de test (éviter un fichier d'entraînement)
ground_truth = "./entrainements/mainCdS02_Konv002_03/test/CdS02_Konv002-01_0005.xml"
main = ground_truth.split('/')[2]
# image est le chemin vers l'image associée au précédent fichier
image = "./entrainements/mainCdS02_Konv002_03/test/CdS02_Konv002-01_0005.jpg"

model = "./modeles-rec/cds_lectcm_04_mains_01.mlmodel"
# Out:
# mainCdS02_Konv002_03

# %% [markdown]
# ## Étape 4 : Configuration des paramètres d'évaluation (optionnelle)
#
# Vous pouvez ignorer cette étape en utilisant les paramètres par défaut ci-dessous en éxécutant la cellule.
#
# ⚒️ Options disponibles
# -------------------
#
# * **transforms** : Permet d'appliquer des transformations au texte (*pre-processing*) afin de faire varier les scores en sortie, vous pouvez combiner ces options ex. transforms="DLP" (attention l'ordre peut avoir un impact).
#   - **D** : Supprime l'ensemble des chiffres et nombres;
#   - **U** : Majusculise le texte;
#   - **L** : Minusculise le texte;
#   - **P** : Supprime la ponctuation;
#   - **X** : Supprime les signes diacritiques;
#
# * **verbosity** : Permet de récupérer des logs d'éxécution pour suivre le processus.
#
# * **truncate** : Option à utiliser pour tronquer le résultat final.
#
# * **percent** : Option pour afficher un résultat en pourcentage.
#
# * **round_digits** : Option pour régler les chiffres après la virgule.

# %%
transforms="XP"
verbosity=False
truncate=True
percent=True
round_digits='0.01'

# %% [markdown]
# ## Étape 5 : Création de l'objet Kami pour opérer les scores
#
#
# 🚀 Lancer la cellule. En cas d'erreur vérifier bien que vous avez lancer la cellule précédente.
#
# Si vous utilisez du XML en vérité terrain, l'erreur : `Recognizers with segmentation types set() will be applied to segmentation of type baselines. This will likely result in severely degraded performace` apparait. Vous pouvez ignorer ces avertissements et passer à la suite.

# %%
kevaluator = Kami(ground_truth,  
         model=model, 
         image=image,  
         apply_transforms=transforms,
         verbosity=verbosity, 
         truncate=truncate, 
         percent=True,  
         round_digits=round_digits)

# %% [markdown]
# ## Étape 6 : Visualiser les formes de textes (optionnelle)
#
# 🚀 Lancer la cellule pour visualiser le texte de vérité terrain et le texte prédit, avec ou sans transformations selon les options précédémment choisies.
#
# ⚠️ Il se peut que la taille de votre texte soit trop grande dans ce cas sélectionner des parties du texte via l'index pour afficher des extraits.

# %%
print("GROUND TRUTH TEXT : \n")
print(kevaluator.reference)

# via l'index (en cas de texte trop long) :
# print(kevaluator.reference[0:50])

print(f"\n{'-' * 20}\n")

print("PREDICTION TEXT : \n")
print(kevaluator.prediction)

print(f"\n{'=' * 20}\n")

print("GROUND TRUTH TEXT (with transforms) : \n")
print(kevaluator.reference_preprocess)

print(f"\n{'*' * 20}\n")

print("PREDICTION TEXT (with transforms) : \n")
print(kevaluator.prediction_preprocess)

print(f"\n{'*' * 20}\n")
# Out:
# GROUND TRUTH TEXT :
#
# Correspondance intime
# Les lettres qui forment cette Correspondance sont celles
# de mon mari et les miennes ; elles forment aussi une section en-
# tièrement séparée. (1)
# Je me propose d'en faire un choix et de les copier moi-même
# plus tard. Presque toutes ayant été crites dans les troubles de mon
# 1er. ménage, elles me rappeleront une foule de Souvenirs nécessaires
# à la redaction de cette partie de mes Mémoires.
# Correspondance d'affaires.
# Toutes ces lettres sont relatives à la fortune, à des procès,
# à des circonstances quelconques de ce genre dont il peut être néces-
# saire de garder des souvenirs ou des preuves, surtout comme venant
# à l'appui des Mémoires. J'ai gardé les brouillons d'une partie
# de celles que j'ai écritures lorsqu'elles étaient relatives à des
# circonstances essentielles. Il en sera fait un choix, ainsi que
# des réponses ou lettres de quelques avocats célèbres et elles seront
# copiés sous ce titre : Choix de lettres d'affaires faisant suite
# à la Correspondance particulière. ‒
# (1) Petite armoire No. 25.
# Plan de cette seconde Copie
# (dites 2de. Copie de la Cor: génle.)
# La première Copie qui porte le même titre et qui n'é-
# tait que littéraire, ne pouvant me guider que sous un seul rap-
# port dans la rédaction de mes mémoires, je me suis décidée (en
# 1832) à ajouter à cette second Copie les lettres des Correspon-
# dances ci dessus expliquées qui peuvent établir et me rappe-
# ler toutes les circonstances de ma vie littéraire et sociale. J'y
# fait de plus ajouter beaucoup de vers de société, de circons-
# tance, des Poésies legères que je n'aurais pu placer convena-
# blement dans l'Edition de mes ouvrages, et, enfin, de plusieurs
# Notices sur les personnes plus ou moins célèbres dont les lettres
# font partie de cette Correspondance. Il y a été joint aussi beau-
# coup de petites lettres et de billets insignifiants, qui ne dépen-
# dent d'aucune correspondance, qui seront plus tard supprimés,
# et qui ne doivent servir qu'à rappeler des dates et des souvenirs
# comme je vais l'expliquer. Cette seconde Copie contiendra donc :
# 1o. toutes les lettres ou réponses de la Cor: génle. littéraire.
# 2o. Toutes celles de la Cor: part: que j'ai écritres à mes amis,
# et celles de leurs lettres ou réponses qui se rattachent à quelques
# circonstances littéraires ou autres, et qui me paraitront néces-
# saires pour la rédaction de mes Mémoires. ‒
# 3o. Toutes une partie de celles de la Correspondance
# secrète ou confidentielle, lettre et réponses. ‒
# 4o. Quelques unes de la Correspondance intime quand
# elles seront relatives à quelques faits essentiels. ‒
# 5o. Un choix de lettres d'affaires idem. ‒
# Nota. La Correspondance générale comprenant toutes les
#
# --------------------
#
# PREDICTION TEXT :
#
# Correspondance intime.
# Les lettres qui forment cette Correspondance sont celles
# de mon mari et les miennes ; elles forment aussi une Section en-
# tièrement séparée. Cl
# Je me propose d'en faire un choix et de les copier moi-même
# plus tard. Presque toutes ayant été crites dans les troubles de mon
# 1er ménage, elles me rappeleront une foule de Pouvenirs nécessaires
# à la redaition de cette partie de mes Mémoires.
# Correspondance d'affaires.
# Foutits ces lettres sont relatives à la fortune, à des procès,
# à des circonstances queleonques de ce genré dont il peut être néces-
# saire de garder des souvenirs ou des preuves, suertout comme venant
# à l'appui des Mémoires. J'ai gardé les brouillons d'une partie
# de celles que j'ai écrites lorsqu elles étaient relatives à des
# circonstances essentiilles. Il en sera fait un choix, ainsi que
# des réponses ou lettres dequelques avocats éclebres et elles seront
# copiez sous ce titre : Choix de lettres d'affaires faisant suite
# à la Correspondance particutière.‒
# C.) Pétite armoire Ken.
# Plan de cette seconde Copie
# (dites 2de. Copie de la tor: génte
# La première Copie qui porte le même têtre et qui n'é-
# tait que littéraire, ne pouvant me quider que sons un seul rap-
# port dans la rédaction de mes memoires, je me suis décidée (en
# 1832) à ajouter à catte seconde Copie les lettres des Corres pon-
# dances ci dessus expliguées qui peuvent établir et me rappe-
# ler toutes les circonstances de ma vie littéraire et socéale. J'y
# ai fait de plus ajouter beaucoup de vers de société, de cercons-
# tance, des Poésiès legères que je n'aurais pu placer convena-
# blement dans l'Edition de mes ouvrages, et, enfin, de plusieurs
# Notices sur les personnes plus ou moins célébres dont les lettres
# font partie de cette Correspondance. Il y a été joint aussi beau-
# coup de petites lettres et de billets insignifiants, qui ne dépen-
# dett d'aucune correspondance, qui seront plus tard supprimés,
# et qui ne doivent servir qu'à rappeler des dates et des souvenere
# comme je vais l'expliguer. Cette séconde Copie contiendra donc .:
# Ve toutes les lettres ou réponses de la Cor. genle littéraire.
# 20. Doutes celles de la Cor. part. que j'ai écrites à mes amis
# et celles de leurs lettres ou réponses qui se rattachent à quelques
# circonstances littéraires ou autres, et qui me paraitront réces-
# saires pour la rédaction de mes Mémoires. ‒
# de Toutes ou une partés de celles de la Correspondance
# secrête ou confidentielle, lettres et réponses.‒
# le. Quelques unes de la Correspondance intime quand
# elles seront relatives à quelques faits essentiels.‒
# 5e. Ma choix de lettres d'affaires idem. ‒
# Nota. La Correspondance générale comprenant toutes les
#
# ====================
#
# GROUND TRUTH TEXT (with transforms) :
#
# Correspondance intime
# Les lettres qui forment cette Correspondance sont celles
# de mon mari et les miennes  elles forment aussi une section en
# tierement separee 1
# Je me propose den faire un choix et de les copier moimeme
# plus tard Presque toutes ayant ete crites dans les troubles de mon
# 1er menage elles me rappeleront une foule de Souvenirs necessaires
# a la redaction de cette partie de mes Memoires
# Correspondance daffaires
# Toutes ces lettres sont relatives a la fortune a des proces
# a des circonstances quelconques de ce genre dont il peut etre neces
# saire de garder des souvenirs ou des preuves surtout comme venant
# a lappui des Memoires Jai garde les brouillons dune partie
# de celles que jai ecritures lorsquelles etaient relatives a des
# circonstances essentielles Il en sera fait un choix ainsi que
# des reponses ou lettres de quelques avocats celebres et elles seront
# copies sous ce titre  Choix de lettres daffaires faisant suite
# a la Correspondance particuliere -
# 1 Petite armoire No 25
# Plan de cette seconde Copie
# dites 2de Copie de la Cor genle
# La premiere Copie qui porte le meme titre et qui ne
# tait que litteraire ne pouvant me guider que sous un seul rap
# port dans la redaction de mes memoires je me suis decidee en
# 1832 a ajouter a cette second Copie les lettres des Correspon
# dances ci dessus expliquees qui peuvent etablir et me rappe
# ler toutes les circonstances de ma vie litteraire et sociale Jy
# fait de plus ajouter beaucoup de vers de societe de circons
# tance des Poesies legeres que je naurais pu placer convena
# blement dans lEdition de mes ouvrages et enfin de plusieurs
# Notices sur les personnes plus ou moins celebres dont les lettres
# font partie de cette Correspondance Il y a ete joint aussi beau
# coup de petites lettres et de billets insignifiants qui ne depen
# dent daucune correspondance qui seront plus tard supprimes
# et qui ne doivent servir qua rappeler des dates et des souvenirs
# comme je vais lexpliquer Cette seconde Copie contiendra donc
# 1o toutes les lettres ou reponses de la Cor genle litteraire
# 2o Toutes celles de la Cor part que jai ecritres a mes amis
# et celles de leurs lettres ou reponses qui se rattachent a quelques
# circonstances litteraires ou autres et qui me paraitront neces
# saires pour la redaction de mes Memoires -
# 3o Toutes une partie de celles de la Correspondance
# secrete ou confidentielle lettre et reponses -
# 4o Quelques unes de la Correspondance intime quand
# elles seront relatives a quelques faits essentiels -
# 5o Un choix de lettres daffaires idem -
# Nota La Correspondance generale comprenant toutes les
#
# ********************
#
# PREDICTION TEXT (with transforms) :
#
# Correspondance intime
# Les lettres qui forment cette Correspondance sont celles
# de mon mari et les miennes  elles forment aussi une Section en
# tierement separee Cl
# Je me propose den faire un choix et de les copier moimeme
# plus tard Presque toutes ayant ete crites dans les troubles de mon
# 1er menage elles me rappeleront une foule de Pouvenirs necessaires
# a la redaition de cette partie de mes Memoires
# Correspondance daffaires
# Foutits ces lettres sont relatives a la fortune a des proces
# a des circonstances queleonques de ce genre dont il peut etre neces
# saire de garder des souvenirs ou des preuves suertout comme venant
# a lappui des Memoires Jai garde les brouillons dune partie
# de celles que jai ecrites lorsqu elles etaient relatives a des
# circonstances essentiilles Il en sera fait un choix ainsi que
# des reponses ou lettres dequelques avocats eclebres et elles seront
# copiez sous ce titre  Choix de lettres daffaires faisant suite
# a la Correspondance particutiere-
# C Petite armoire Ken
# Plan de cette seconde Copie
# dites 2de Copie de la tor gente
# La premiere Copie qui porte le meme tetre et qui ne
# tait que litteraire ne pouvant me quider que sons un seul rap
# port dans la redaction de mes memoires je me suis decidee en
# 1832 a ajouter a catte seconde Copie les lettres des Corres pon
# dances ci dessus expliguees qui peuvent etablir et me rappe
# ler toutes les circonstances de ma vie litteraire et soceale Jy
# ai fait de plus ajouter beaucoup de vers de societe de cercons
# tance des Poesies legeres que je naurais pu placer convena
# blement dans lEdition de mes ouvrages et enfin de plusieurs
# Notices sur les personnes plus ou moins celebres dont les lettres
# font partie de cette Correspondance Il y a ete joint aussi beau
# coup de petites lettres et de billets insignifiants qui ne depen
# dett daucune correspondance qui seront plus tard supprimes
# et qui ne doivent servir qua rappeler des dates et des souvenere
# comme je vais lexpliguer Cette seconde Copie contiendra donc
# Ve toutes les lettres ou reponses de la Cor genle litteraire
# 20 Doutes celles de la Cor part que jai ecrites a mes amis
# et celles de leurs lettres ou reponses qui se rattachent a quelques
# circonstances litteraires ou autres et qui me paraitront reces
# saires pour la redaction de mes Memoires -
# de Toutes ou une partes de celles de la Correspondance
# secrete ou confidentielle lettres et reponses-
# le Quelques unes de la Correspondance intime quand
# elles seront relatives a quelques faits essentiels-
# 5e Ma choix de lettres daffaires idem -
# Nota La Correspondance generale comprenant toutes les
#
# ********************

# %% [markdown]
# ## Étape 7 : Visualiser les résultats obtenus dans un tableau
#
#
# 🚀 Lancer la cellule pour afficher les résultats.
#
# Précisions sur les métriques
# ----------------------------
#
# Opérations (utilisés pour la distance) :
#
# * **hits** : nombre de caractères similaires entre la vérité terrain et la prédiction;
# * **substitutions** : nombre de substitutions opérées entre la vérité terrain et la prédiction;
# * **deletions** : nombre de suppressions opérées entre la vérité terrain et la prédiction;
# * **insertions** : nombre d'insertions opérées entre la vérité terrain et la prédiction;
#
# Distance d'édition :
#
# * **levensthein_distance_char** : distance de Levenshtein calculée sur les caractères;
# * **levensthein_distance_words** : distance de Levenshtein calculée sur les mots;
# * **hamming_distance** : distance de Hamming (Ø si les chaînes ne font pas exactement la même longueur, nombre si les chaînes font la même longueur mais que certains caractères divergent).
#
# Scores généraux HTR/OCR :
#
# * **wer** : *word error rate* ou taux d'erreur par mots. Le $WER$ est calculé sur la base des mots de la vérité terrain par rapport à la prédiction réalisée par le modèle. Il est généralement compris entre $[0, 1.0]$, plus il est proche de 0 plus la reconnaissance est bonne. En revanche, il n'est pas borné : une mauvaise reconnaissance peut entrainer un $WER > 1.0$.
# Il est calculé
# \begin{align}
# \frac{S + D + I}{N}
# \end{align}
# où $S$ est le nombre de substitions de mots, $D$ le nombre de mots surpprimés, et $I$ le nombre de mots insérés; $N$ correspond au nombre total de mots dans la chaîne de référence; cela correspond également à
# \begin{align}
# \frac{distance \, de \, Levenshtein \, sur \, les \, mots}{N}
# \end{align}
#
# * **cer** : *character error rate* ou taux d'erreur par caractères. Le $CER$ est calculé sur la base des caractères de la vérité terrain par rapport à la prédiction réalisée par le modèle. Il est généralement compris entre $[0, 1.0]$, plus il est proche de 0 plus la reconnaissance est bonne. En revanche, il n'est pas borné : une mauvaise reconnaissance peut entrainer un $CER > 1.0$.
# Il est calculé
# \begin{align}
# \frac{S + D + I}{N}
# \end{align}
# où $S$ est le nombre de substitions de caractères, $D$ le nombre de caractères surpprimés, et $I$ le nombre de caractères insérés; $N$ correspond au nombre total de caractères dans la chaîne de référence; cela correspond également à
# \begin{align}
# \frac{distance \, de \, Levenshtein \, sur \, les \, caractères}{N}
# \end{align}
#
# * **wacc** 	: *word accuracy* ou taux de reconnaissance par mots calculé
# \begin{align}
# 1- WER
# \end{align}
# En cas de très mauvaise reconnaissance ce taux peut-être négatif.
#
# Scores de précision (emprunté à l'évaluation de la reconnaissance de la parole - système ASR) :
#
# * **mer** : *match error rate*
# * **cil** : *character information lost*
# * **cip** : *charcter information preserve*
#
#  Voir :
#
#  - [Morris, A. et al. “From WER and RIL to MER and WIL: improved evaluation measures for connected speech recognition.” INTERSPEECH (2004).](https://www.semanticscholar.org/paper/From-WER-and-RIL-to-MER-and-WIL%3A-improved-measures-Morris-Maier/8516531ff3bd874b66b811f0bd4e21a2d6b10e54?p2df)
#
#  - [Errattahi, R. et al. "Automatic Speech Recognition Errors Detection and Correction: A Review". Procedia Computer Science. (2018).](https://www.researchgate.net/publication/324427003_Automatic_Speech_Recognition_Errors_Detection_and_Correction_A_Review)

# %%
metadatas = {}
metrics = {}

now = datetime.now()
metadatas['DATETIME'] = now.strftime("%d_%m_%Y_%H:%M:%S")
metadatas['IMAGE'] = image
metadatas['GROUND_TRUTH'] = ground_truth
metadatas['MODEL'] = model

for key, value in kevaluator.scores.board.items():
  if type(value) != dict and key not in ['levensthein_distance_char', 
                                           'levensthein_distance_words',
                                           'hamming_distance', 
                                           'wer', 
                                           'cer', 
                                           'wacc', 
                                           'mer', 
                                           'cil', 
                                           'cip', 
                                           'hits', 
                                           'substitutions', 
                                           'deletions', 
                                           'insertions']:
    metadatas[key] = value
  else:
    metrics[key] = value

print(f"************* EVALUATION HTR/OCR REPORT FROM KAMI - {metadatas['DATETIME']} / MODEL : {metadatas['MODEL']} *************\n")

for key, value in metadatas.items():
  print(f"- {key} : {value}")

print("\n")

try:
  df_metrics = pd.DataFrame.from_dict(metrics)
except:
  df_metrics = pd.DataFrame.from_dict(metrics, orient='index')

df_metrics
# Out:
# ************* EVALUATION HTR/OCR REPORT FROM KAMI - 02_06_2022_11:38:48 / MODEL : ./modeles-rec/cds_lectcm_04_mains_01.mlmodel *************
#
# - DATETIME : 02_06_2022_11:38:48
# - IMAGE : ./entrainements/mainCdS02_Konv002_03/test/CdS02_Konv002-01_0005.jpg
# - GROUND_TRUTH : ./entrainements/mainCdS02_Konv002_03/test/CdS02_Konv002-01_0005.xml
# - MODEL : ./modeles-rec/cds_lectcm_04_mains_01.mlmodel
# - Total_char_removed_from_reference : 89
# - Total_char_removed_from_prediction : 80
# - Total_diacritics_removed_from_reference : 74
# - Total_diacritics_removed_from_prediction : 77
# - Length_reference : 2656
# - Length_prediction : 2651
# - Length_reference_transformed : 2567
# - Length_prediction_transformed : 2571
#                            default remove_punctuation remove_diacritics  \
# levensthein_distance_char       90                 75                80
# levensthein_distance_words      67                 60                60
# hamming_distance                 Ø                  Ø                 Ø
# wer                          15.19              13.69              13.6
# cer                           3.38               2.92              3.01
# wacc                          84.8               86.3             86.39
# wer_hunt                     14.17              12.67             12.58
# mer                           3.37                2.9              2.99
# cil                           5.53               4.92               4.8
# cip                          94.46              95.07             95.19
# hits                          2579               2505              2589
# substitutions                   59                 53                49
# deletions                       18                  9                18
# insertions                      13                 13                13
#
#                            all_transforms
# levensthein_distance_char              65
# levensthein_distance_words             52
# hamming_distance                        Ø
# wer                                 11.87
# cer                                  2.53
# wacc                                88.12
# wer_hunt                            10.84
# mer                                  2.51
# cil                                  4.15
# cip                                 95.84
# hits                                 2515
# substitutions                          43
# deletions                               9
# insertions                             13

# %% [markdown]
# ## Étape 8 : Exporter les résultats en CSV
#
# 🚀 Lancer la cellule.

# %%
name_csv = f"rapport-kami-{main}.csv"

with open(f"./mains/{name_csv}", 'w')  as csv_file:
  writer = csv.writer(csv_file, 
                      delimiter=',',
                      quotechar='|', 
                      quoting=csv.QUOTE_MINIMAL)
  for key, value in metadatas.items():
    row = []
    row.append(key)
    row.append(value)
    writer.writerow(row)

df_metrics.to_csv(f"./mains/{name_csv}", mode='a', header=True)

print(f"Le rapport a été correctement écrit dans le fichier ./mains/{name_csv}")
# Out:
# Le rapport a été correctement écrit dans le fichier ./mains/rapport-kami-mainCdS02_Konv002_03.csv
